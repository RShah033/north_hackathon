# %%
#Hypothetical example

import numpy as np
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
data = pd.read_csv('Assets.csv')
data
# Out:
#     Title        Asset Type  Location      x    y Water/Sewage Date Installed  \
# 0       1        Water Pump         0      0    0        Water     01/04/2023
# 1       2  Sewage Treatment         0      8    5       Sewage     01/12/2023
# 2       3        Water Pump         1      5    8        Water      4/13/2017
# 3       4        Water Pump         1      1    1        Water     01/06/2023
# 4       6  Sewage Treatment         0  3,000  380        Water     01/02/2023
# 5       9        Water Pipe         0      3    9        Water     04/10/2019
# 6       8       Sewage Pipe         0      2    6       Sewage     12/22/2021
# 7      21       Sewage Pipe         0     17   30        Water     01/11/2023
# 8      10         Reservoir         1      2    9        Water            NaN
# 9       7        Water Pipe         0      2    3        Water     01/04/2023
# 10    123       Sewage Pipe         0      6    1       Sewage      1/24/2036
# ...

# %%
features = ['Location', 'Run Time (s)', 'Pump Vibration (mm/s)'] #change features - see how accuracy changes

# %%
data = data.fillna(0)

X = data[features]
y = data.Score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, random_state=0)
print("\nX_train:\n")
print(X_train.head())
print(X_train.shape)

print("\nX_test:\n")
print(X_test.head())
print(X_test.shape)
# Out:
# X_train:
#
#     Location  Run Time (s)  Pump Vibration (mm/s)
# 11         1        400000                    4.0
# 2          1          2000                    2.0
# 13         0        404028                    0.0
# 9          0           100                    0.0
# 1          0        100000                    0.0
# (11, 3)
#
# X_test:
#
#    Location  Run Time (s)  Pump Vibration (mm/s)
# 8         1      10000000                    0.0
# 6         0         18800                    0.0
# 4         0           600                    0.0
# (3, 3)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
linreg = LinearRegression()
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = linreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(linreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: -9.93
